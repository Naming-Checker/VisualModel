# %%
import pandas as pd

# %%
frame = pd.read_csv('../data/similar.csv', header=None, index_col=None)
#frame = frame.sample(frac=1) # Random
train = frame[frame.reset_index().index % 5 != 0] # 80% training size
valid = frame[frame.reset_index().index % 5 == 0]
train.to_csv(f'../data/similar_train.csv', header=None, index=False)
valid.to_csv(f'../data/similar_valid.csv', header=None, index=False)
